# %%
mkdir -p notebook
touch notebook/02_retrieval_local_test.ipynb
# Out:
#   Cell In[1], line 2
#     touch notebook/02_retrieval_local_test.ipynb
#                      ^
# SyntaxError: invalid decimal literal

# %%
cd ~/sprint-ai-mid-project_team3
source $HOME/.local/bin/env
uv --version
uv pip install -r requirements.txtchmod 700 ~/.ssh

# %%
mkdir -p ~/.ssh
